# %%
import logging
import pandas
import xlsxwriter
import xml.etree.ElementTree as ET
import PyCIM
import cim2busbranch
import pypower.api as pypower

logging.basicConfig(level=logging.INFO)

print("Hello, This is CIM import parser")

# %%
cim_topo = PyCIM.cimread('D:\Programming\Python_Micro_Codes\CIM_import_program\MIKRONIKA_23A10h_short.xml')
#d = PyCIM.RDFXMLReader.xmlns('D:\Programming\Python_Micro_Codes\CIM_import_program\MIKRONIKA_23A10h_short.xml')
#print(d)

# %%
print(cim_topo)

# %%
print(cim_topo)

# %%
for x in cim_topo:
    print(x)
